# %%
import requests
import json

# %%
# def download_file(url, destination):
#     response = requests.get(url)
#     with open(destination, 'wb') as file:
#         file.write(response.content)

# def process_tcf1(tcf1_data):
#     # Your TCF1 processing logic goes here
#     processed_data = tcf1_data  # Placeholder, replace with actual processing

#     # Return the processed data
#     return processed_data

def process_tcf2(tcf2_data):
    # Your TCF2 processing logic goes here
    processed_data = None  # Placeholder, replace with actual processing

    # Return the processed data
    return processed_data

def main():
    # Replace these URLs with the actual endpoints for TCF1 and TCF2
#     tcf1_url = 'https://example.com/tcf1_endpoint'
#     tcf2_url = 'https://example.com/tcf2_endpoint'

#     # Download TCF1 data
  # tcf1_response = requests.get("https://briot.in/clients/")
  # tcf1_data = json.loads(tcf1_response.text)
  # print("tcf1_response",tcf1_response.text)
    
    # Process TCF1 data
#     process_tcf1(tcf1_data)

    # Download TCF2 data
    tcf2_response = requests.get("https://briot.in/clients/")
    print("tcf2_response", tcf2_response.text)
#     tcf2_data = json.loads(tcf2_response.text)
#     print("TCF2", tcf2_data)
    
    # Process TCF2 data
#     process_tcf2(tcf2_data)

    # Add your logic to trigger downloads based on TCF1 and TCF2 data
    # For example:
   # if some_condition_based_on_tcf1_and_tcf2:
    #     download_file('https://example.com/download_url', 'destination_file_path')

if __name__ == "__main__":
    main()
# Out:
# tcf2_response <head><title>Not Acceptable!</title></head><body><h1>Not Acceptable!</h1><p>An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.</p></body></html>
